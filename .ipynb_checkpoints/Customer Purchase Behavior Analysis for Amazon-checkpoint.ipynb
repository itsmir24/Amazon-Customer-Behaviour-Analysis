# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  You have been handed three datasets (Product Information, Transaction Details, and Customer Demographics) for analysis.
#  However, some of the data contains missing values, which could affect the accuracy of the insights.
#  Your task is to identify and handle the missing values in the dataset, ensuring that the data is clean and ready for analysis.
#  Use appropriate techniques to fill in missing numerical values, such as prices or quantities.

# %%
df_c=pd.read_excel(r"C:\Users\Mir Abdul Malique\Downloads\Customer Behaviour Amazon\Customer_Demographics_Purchase_History_With_Missing_Numeric.xlsx")

# %%
df_c
# Out:
#       Customer_ID Customer_Name   Age  Gender       Location Product_Category  \
# 0           17270          John  56.0   Other       New York            Books
# 1           10860           Eve  33.0   Other        Houston  Home Appliances
# 2           15390          John  50.0  Female        Houston         Clothing
# 3           15191           Eve  66.0   Other  San Francisco      Electronics
# 4           15734           Eve  38.0  Female       New York             Toys
# ...           ...           ...   ...     ...            ...              ...
# 1995        10661       Charlie  61.0    Male    Los Angeles  Home Appliances
# 1996        13374           Eve  41.0  Female        Chicago            Books
# 1997        19208         Alice  58.0  Female        Houston             Toys
# 1998        10207          John  18.0  Female  San Francisco            Books
# 1999        12665         Alice  68.0   Other       New York         Clothing
#
#       Product_ID       Purchase_Date  Purchase_Amount Payment_Method  Rating  \
# 0            674 2020-01-01 00:00:00       491.643012           Cash     NaN
# 1            393 2020-01-01 01:00:00       144.326722           Cash     5.0
# 2            995 2020-01-01 02:00:00       109.301892  Bank Transfer     NaN
# 3            405 2020-01-01 03:00:00       226.655516  Bank Transfer     2.0
# 4            353 2020-01-01 04:00:00        37.851880  Bank Transfer     2.0
# ...          ...                 ...              ...            ...     ...
# 1995         989 2020-03-24 03:00:00       168.291356    Credit Card     5.0
# 1996         409 2020-03-24 04:00:00       237.252493  Bank Transfer     5.0
# 1997         617 2020-03-24 05:00:00       213.388283         PayPal     4.0
# 1998         113 2020-03-24 06:00:00        83.056883  Bank Transfer     2.0
# 1999         231 2020-03-24 07:00:00       479.331469         PayPal     2.0
#
#      Feedback_Comments
# 0                  NaN
# 1                 Good
# 2                  NaN
# 3            Excellent
# 4                  NaN
# ...                ...
# 1995         Excellent
# 1996           Average
# 1997              Good
# 1998               NaN
# 1999               NaN
#
# [2000 rows x 12 columns]

# %%
df_p=pd.read_csv(r"C:\Users\Mir Abdul Malique\Downloads\Customer Behaviour Amazon\Product_Information_With_Missing_Numeric.csv")

# %%
df_p
# Out:
#       Product_ID  Product_Name         Category       Price  Stock_Level  \
# 0            202          Book  Home Appliances  838.665080          290
# 1            535          Book            Books  212.950114          332
# 2            960         Phone  Home Appliances  452.327541          179
# 3            370         Shirt             Toys  215.423366          414
# 4            206  Refrigerator      Electronics  279.182380          357
# ...          ...           ...              ...         ...          ...
# 1995         667         Phone         Clothing  143.191788           57
# 1996         139         Shirt            Books  426.145366           62
# 1997         965         Phone             Toys  767.195632          155
# 1998         139         Phone         Clothing  902.305995          448
# 1999         958          Book      Electronics  671.521631          427
#
#         Supplier  Discount  Rating
# 0     Supplier C         3       3
# 1     Supplier A        21       2
# 2     Supplier B        21       2
# 3     Supplier A        36       5
# 4     Supplier B        38       5
# ...          ...       ...     ...
# 1995  Supplier C        25       3
# 1996  Supplier A        19       2
# 1997  Supplier B        41       4
# 1998  Supplier B        27       5
# 1999  Supplier C        19       4
#
# [2000 rows x 8 columns]

# %%
df_t=pd.read_json(r"C:\Users\Mir Abdul Malique\Downloads\Customer Behaviour Amazon\Transaction_Details_With_Missing_Numeric.json",lines=True)

# %%
df_t
# Out:
#       Transaction_ID  Customer_ID  Product_ID  Shipping_Date Delivery_Status  \
# 0             115795        18859         751   1.609459e+12       Delivered
# 1             100860        17818         198   1.609463e+12       Delivered
# 2             176820        14728         377   1.609466e+12       Delivered
# 3             154886        12624         662   1.609470e+12       Cancelled
# 4             106265        15738         762            NaN      In Transit
# ...              ...          ...         ...            ...             ...
# 3995          122440        14541         280   1.623841e+12       Delivered
# 3996          135205        13257         118   1.623845e+12       Cancelled
# 3997          180811        16213         325   1.623848e+12      In Transit
# 3998          155103        14869         572   1.623852e+12      In Transit
# 3999          170812        11561         194   1.623856e+12       Delivered
#
#      Return_Status  Feedback_Rating Return_Reason
# 0         Returned                5     No Reason
# 1         Returned                1    Wrong Item
# 2         Returned                4     No Reason
# 3         Returned                4
# 4     Not Returned                1
# ...            ...              ...           ...
# 3995      Returned                1       Damaged
# 3996  Not Returned                1
# 3997  Not Returned                4    Wrong Item
# 3998  Not Returned                1
# 3999      Returned                1    Wrong Item
#
# [4000 rows x 8 columns]

# %%
df_c.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Age', 'Gender', 'Location',
#        'Product_Category', 'Product_ID', 'Purchase_Date', 'Purchase_Amount',
#        'Payment_Method', 'Rating', 'Feedback_Comments'],
#       dtype='object')

# %%
df_t.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Product_ID', 'Shipping_Date',
#        'Delivery_Status', 'Return_Status', 'Feedback_Rating', 'Return_Reason'],
#       dtype='object')

# %%
df_p.columns
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Price', 'Stock_Level',
#        'Supplier', 'Discount', 'Rating'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning of Customer DataFrame
#  Checking Null values: (isnull()) ,
#  Checking Duplicates value: (isduplicated()) ,
#  Checking inconsistent data

# %%
df_c.isnull()
# Out:
#       Customer_ID  Customer_Name    Age  Gender  Location  Product_Category  \
# 0           False          False  False   False     False             False
# 1           False          False  False   False     False             False
# 2           False          False  False   False     False             False
# 3           False          False  False   False     False             False
# 4           False          False  False   False     False             False
# ...           ...            ...    ...     ...       ...               ...
# 1995        False          False  False   False     False             False
# 1996        False          False  False   False     False             False
# 1997        False          False  False   False     False             False
# 1998        False          False  False   False     False             False
# 1999        False          False  False   False     False             False
#
#       Product_ID  Purchase_Date  Purchase_Amount  Payment_Method  Rating  \
# 0          False          False            False           False    True
# 1          False          False            False           False   False
# 2          False          False            False           False    True
# 3          False          False            False           False   False
# 4          False          False            False           False   False
# ...          ...            ...              ...             ...     ...
# 1995       False          False            False           False   False
# 1996       False          False            False           False   False
# 1997       False          False            False           False   False
# 1998       False          False            False           False   False
# 1999       False          False            False           False   False
#
#       Feedback_Comments
# 0                  True
# 1                 False
# 2                  True
# 3                 False
# 4                  True
# ...                 ...
# 1995              False
# 1996              False
# 1997              False
# 1998               True
# 1999               True
#
# [2000 rows x 12 columns]

# %%
df_c.isnull().sum()
# Out:
# Customer_ID            0
# Customer_Name        100
# Age                  100
# Gender                 0
# Location               0
# Product_Category       0
# Product_ID             0
# Purchase_Date          0
# Purchase_Amount      200
# Payment_Method         0
# Rating               140
# Feedback_Comments    901
# dtype: int64

# %%
df_c.describe()
# Out:
#         Customer_ID          Age   Product_ID                  Purchase_Date  \
# count   2000.000000  1900.000000  2000.000000                           2000
# mean   15022.171500    43.696316   546.669000  2020-02-11 15:29:59.999999744
# min    10001.000000    18.000000   100.000000            2020-01-01 00:00:00
# 25%    12585.750000    31.000000   320.750000            2020-01-21 19:45:00
# 50%    15104.500000    43.000000   551.000000            2020-02-11 15:30:00
# 75%    17408.250000    57.000000   763.000000            2020-03-03 11:15:00
# max    19998.000000    69.000000   998.000000            2020-03-24 07:00:00
# std     2865.577794    14.902947   259.999847                            NaN
#
#        Purchase_Amount       Rating
# count      1800.000000  1860.000000
# mean        257.954370     2.978495
# min          10.077295     1.000000
# 25%         134.525844     2.000000
# 50%         257.545509     3.000000
# 75%         383.819725     4.000000
# max         499.839871     5.000000
# std         142.217621     1.409478

# %%
#IQR=(383.819725-134.525844) 
#lb=134.525844-1.5*IQR
#ub=383.819725+1.5*IQR
#print(IQR)
#print(lb)
#print(ub)

# %%
df_c['Customer_Name'].fillna("Unknown",inplace=True)
df_c['Age'].fillna(df_c['Age'].mean(),inplace=True)
df_c['Purchase_Amount'].fillna(df_c['Purchase_Amount'].mean(),inplace=True)
df_c['Rating'].fillna(df_c['Rating'].mode()[0],inplace=True)
df_c.drop('Feedback_Comments',axis=1,inplace=True)

# %%
df_c.isna().sum()
# Out:
# Customer_ID         0
# Customer_Name       0
# Age                 0
# Gender              0
# Location            0
# Product_Category    0
# Product_ID          0
# Purchase_Date       0
# Purchase_Amount     0
# Payment_Method      0
# Rating              0
# dtype: int64

# %%
df_c.duplicated().sum()
# Out:
# 0

# %%
#if in case there is duplicate present we can use df_c.drop_duplicates(inplace=True)

# %%
#checking if all the necessary columns have respective formats otherwise change it 
#for example df_c['Purchase_Date']=pd.to_datetime(df_c['Purchase_Date'])
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       2000 non-null   int64
#  1   Customer_Name     2000 non-null   object
#  2   Age               2000 non-null   float64
#  3   Gender            2000 non-null   object
#  4   Location          2000 non-null   object
#  5   Product_Category  2000 non-null   object
#  6   Product_ID        2000 non-null   int64
#  7   Purchase_Date     2000 non-null   datetime64[ns]
#  8   Purchase_Amount   2000 non-null   float64
#  9   Payment_Method    2000 non-null   object
#  10  Rating            2000 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 172.0+ KB

# %% [markdown]
# # Data Celaning For Product DataFrame

# %%
df_p.isnull().sum()
# Out:
# Product_ID        0
# Product_Name    100
# Category          0
# Price           200
# Stock_Level       0
# Supplier          0
# Discount          0
# Rating            0
# dtype: int64

# %%
df_p.describe()
# Out:
#         Product_ID        Price  Stock_Level     Discount       Rating
# count  2000.000000  1800.000000  2000.000000  2000.000000  2000.000000
# mean    548.302500   498.858379   237.706000    24.642000     3.002000
# std     266.893188   285.120922   145.723355    14.501517     1.403916
# min     100.000000    20.614966    -1.000000     0.000000     1.000000
# 25%     315.000000   252.041475   110.000000    12.000000     2.000000
# 50%     549.500000   496.512788   234.000000    24.000000     3.000000
# 75%     785.250000   742.232881   360.000000    37.000000     4.000000
# max     998.000000   999.852260   499.000000    49.000000     5.000000

# %%
IQR=742.232881-252.041475
lb=252.041475-1.5*IQR
ub=742.23288+1.5*IQR
print(IQR)
print(lb)
print(ub)
# Out:
# 490.19140600000003
# -483.2456340000001
# 1477.5199890000001

# %%
df_p['Product_Name'].fillna('Unknown',inplace=True)
df_p['Price'].fillna(df_p['Price'].mean(),inplace=True)

# %%
df_p.isnull().sum()
# Out:
# Product_ID      0
# Product_Name    0
# Category        0
# Price           0
# Stock_Level     0
# Supplier        0
# Discount        0
# Rating          0
# dtype: int64

# %%
df_p.duplicated().sum()
# Out:
# 0

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    2000 non-null   int64
#  1   Product_Name  2000 non-null   object
#  2   Category      2000 non-null   object
#  3   Price         2000 non-null   float64
#  4   Stock_Level   2000 non-null   int64
#  5   Supplier      2000 non-null   object
#  6   Discount      2000 non-null   int64
#  7   Rating        2000 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 125.1+ KB

# %% [markdown]
# # Data Celaning For Transaction DataFrame

# %%
df_t.shape
# Out:
# (4000, 8)

# %%
df_t.isnull().sum()
# Out:
# Transaction_ID       0
# Customer_ID          0
# Product_ID           0
# Shipping_Date      200
# Delivery_Status    280
# Return_Status        0
# Feedback_Rating      0
# Return_Reason        0
# dtype: int64

# %%
df_t.describe()
# Out:
#        Transaction_ID   Customer_ID   Product_ID  Shipping_Date  \
# count     4000.000000   4000.000000  4000.000000   3.800000e+03
# mean    149332.371500  14933.221000   556.226500   1.616654e+12
# std      28903.525149   2865.062739   261.650081   4.158782e+09
# min     100055.000000  10001.000000   100.000000   1.609459e+12
# 25%     124054.750000  12510.500000   328.000000   1.613048e+12
# 50%     149249.000000  14845.500000   558.500000   1.616661e+12
# 75%     174534.750000  17381.250000   787.000000   1.620242e+12
# max     199986.000000  19993.000000   998.000000   1.623856e+12
#
#        Feedback_Rating
# count      4000.000000
# mean          2.832250
# std           1.550068
# min          -1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   4000 non-null   int64
#  1   Customer_ID      4000 non-null   int64
#  2   Product_ID       4000 non-null   int64
#  3   Shipping_Date    3800 non-null   float64
#  4   Delivery_Status  3720 non-null   object
#  5   Return_Status    4000 non-null   object
#  6   Feedback_Rating  4000 non-null   int64
#  7   Return_Reason    4000 non-null   object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 250.1+ KB

# %%
df_t['Shipping_Date'] = pd.to_datetime(df_t['Shipping_Date'])

# %%
df_t['Shipping_Date_only']=df_t['Shipping_Date'].dt.date

# %%
df_t.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Product_ID', 'Shipping_Date',
#        'Delivery_Status', 'Return_Status', 'Feedback_Rating', 'Return_Reason',
#        'Shipping_Date_only'],
#       dtype='object')

# %%
df_t.isnull().sum()
# Out:
# Transaction_ID          0
# Customer_ID             0
# Product_ID              0
# Shipping_Date         200
# Delivery_Status       280
# Return_Status           0
# Feedback_Rating         0
# Return_Reason           0
# Shipping_Date_only    200
# dtype: int64

# %%
missing_ship_date=df_t['Shipping_Date'].median()
df_t['Delivery_Status'].fillna(df_t['Delivery_Status'].mode()[0],inplace =True)
df_t['Shipping_Date'].fillna(missing_ship_date,inplace=True)
df_t['Shipping_Date_only'].fillna(missing_ship_date,inplace=True)

# %%
df_t.isnull().sum()
# Out:
# Transaction_ID        0
# Customer_ID           0
# Product_ID            0
# Shipping_Date         0
# Delivery_Status       0
# Return_Status         0
# Feedback_Rating       0
# Return_Reason         0
# Shipping_Date_only    0
# dtype: int64

# %%
merged_df = pd.merge(df_p, df_t, on='Product_ID', how='left')
merged_df = pd.merge(merged_df, df_c, on='Product_ID', how='left',suffixes=('_transaction', '_customer'))

# %%
merged_df.head()
# Out:
#    Product_ID Product_Name         Category      Price  Stock_Level  \
# 0         202         Book  Home Appliances  838.66508          290
# 1         202         Book  Home Appliances  838.66508          290
# 2         202         Book  Home Appliances  838.66508          290
# 3         202         Book  Home Appliances  838.66508          290
# 4         202         Book  Home Appliances  838.66508          290
#
#      Supplier  Discount  Rating_transaction  Transaction_ID  \
# 0  Supplier C         3                   3        170091.0
# 1  Supplier C         3                   3        170091.0
# 2  Supplier C         3                   3        170091.0
# 3  Supplier C         3                   3        170091.0
# 4  Supplier C         3                   3        135195.0
#
#    Customer_ID_transaction  ... Customer_ID_customer Customer_Name   Age  \
# 0                  14776.0  ...              12752.0           Bob  38.0
# 1                  14776.0  ...              12043.0           Bob  37.0
# 2                  14776.0  ...              14904.0           Bob  66.0
# 3                  14776.0  ...              12989.0       Unknown  45.0
# 4                  19369.0  ...              12752.0           Bob  38.0
#
#    Gender       Location Product_Category       Purchase_Date Purchase_Amount  \
# 0    Male  San Francisco             Toys 2020-03-02 23:00:00      134.311447
# 1    Male        Chicago            Books 2020-03-06 22:00:00      475.639185
# 2  Female    Los Angeles  Home Appliances 2020-03-09 07:00:00      257.954370
# 3  Female       New York         Clothing 2020-03-18 04:00:00       12.022306
# 4    Male  San Francisco             Toys 2020-03-02 23:00:00      134.311447
#
#    Payment_Method Rating_customer
# 0   Bank Transfer             3.0
# 1   Bank Transfer             4.0
# 2   Bank Transfer             3.0
# 3            Cash             4.0
# 4   Bank Transfer             3.0
#
# [5 rows x 26 columns]

# %%
merged_df.isnull().sum()
# Out:
# Product_ID                    0
# Product_Name                  0
# Category                      0
# Price                         0
# Stock_Level                   0
# Supplier                      0
# Discount                      0
# Rating_transaction            0
# Transaction_ID               48
# Customer_ID_transaction      48
# Shipping_Date                48
# Delivery_Status              48
# Return_Status                48
# Feedback_Rating              48
# Return_Reason                48
# Shipping_Date_only           48
# Customer_ID_customer       1052
# Customer_Name              1052
# Age                        1052
# Gender                     1052
# Location                   1052
# Product_Category           1052
# Purchase_Date              1052
# Purchase_Amount            1052
# Payment_Method             1052
# Rating_customer            1052
# dtype: int64

# %%
# Remove duplicated Customer_ID columns by keeping the one from customer data
merged_df['Customer_ID'] = merged_df['Customer_ID_customer'].fillna(merged_df['Customer_ID_transaction'])

# %%
# Drop the extra Customer_ID columns and any other redundant columns
merged_df.drop(['Customer_ID_transaction', 'Customer_ID_customer'], axis=1, inplace=True)
# Rename columns to be more descriptive and consistent
merged_df.rename(columns={
    'Product_Name': 'Product Name',
    'Purchase_Amount': 'Purchase Amount',
    'Purchase_Date': 'Purchase Date',
    'Rating_x': 'Product Rating',
    'Rating_y': 'Customer Rating'
}, inplace=True)

# %%
#drop duplicated
merged_df.drop_duplicates(subset=['Product_ID', 'Customer_ID','Transaction_ID'], inplace=True)

# %%
merged_df.head(10)
# Out:
#    Product_ID Product Name         Category      Price  Stock_Level  \
# 0         202         Book  Home Appliances  838.66508          290
# 1         202         Book  Home Appliances  838.66508          290
# 2         202         Book  Home Appliances  838.66508          290
# 3         202         Book  Home Appliances  838.66508          290
# 4         202         Book  Home Appliances  838.66508          290
# 5         202         Book  Home Appliances  838.66508          290
# 6         202         Book  Home Appliances  838.66508          290
# 7         202         Book  Home Appliances  838.66508          290
# 8         202         Book  Home Appliances  838.66508          290
# 9         202         Book  Home Appliances  838.66508          290
#
#      Supplier  Discount  Rating_transaction  Transaction_ID  \
# 0  Supplier C         3                   3        170091.0
# 1  Supplier C         3                   3        170091.0
# 2  Supplier C         3                   3        170091.0
# 3  Supplier C         3                   3        170091.0
# 4  Supplier C         3                   3        135195.0
# 5  Supplier C         3                   3        135195.0
# 6  Supplier C         3                   3        135195.0
# 7  Supplier C         3                   3        135195.0
# 8  Supplier C         3                   3        195084.0
# 9  Supplier C         3                   3        195084.0
#
#                Shipping_Date  ... Customer_Name   Age  Gender       Location  \
# 0 1970-01-01 00:26:50.640000  ...           Bob  38.0    Male  San Francisco
# 1 1970-01-01 00:26:50.640000  ...           Bob  37.0    Male        Chicago
# 2 1970-01-01 00:26:50.640000  ...           Bob  66.0  Female    Los Angeles
# 3 1970-01-01 00:26:50.640000  ...       Unknown  45.0  Female       New York
# 4 1970-01-01 00:26:51.410400  ...           Bob  38.0    Male  San Francisco
# 5 1970-01-01 00:26:51.410400  ...           Bob  37.0    Male        Chicago
# 6 1970-01-01 00:26:51.410400  ...           Bob  66.0  Female    Los Angeles
# 7 1970-01-01 00:26:51.410400  ...       Unknown  45.0  Female       New York
# 8 1970-01-01 00:26:52.278000  ...           Bob  38.0    Male  San Francisco
# 9 1970-01-01 00:26:52.278000  ...           Bob  37.0    Male        Chicago
#
#   Product_Category       Purchase Date  Purchase Amount Payment_Method  \
# 0             Toys 2020-03-02 23:00:00       134.311447  Bank Transfer
# 1            Books 2020-03-06 22:00:00       475.639185  Bank Transfer
# 2  Home Appliances 2020-03-09 07:00:00       257.954370  Bank Transfer
# 3         Clothing 2020-03-18 04:00:00        12.022306           Cash
# 4             Toys 2020-03-02 23:00:00       134.311447  Bank Transfer
# 5            Books 2020-03-06 22:00:00       475.639185  Bank Transfer
# 6  Home Appliances 2020-03-09 07:00:00       257.954370  Bank Transfer
# 7         Clothing 2020-03-18 04:00:00        12.022306           Cash
# 8             Toys 2020-03-02 23:00:00       134.311447  Bank Transfer
# 9            Books 2020-03-06 22:00:00       475.639185  Bank Transfer
#
#   Rating_customer Customer_ID
# 0             3.0     12752.0
# 1             4.0     12043.0
# 2             3.0     14904.0
# 3             4.0     12989.0
# 4             3.0     12752.0
# 5             4.0     12043.0
# 6             3.0     14904.0
# 7             4.0     12989.0
# 8             3.0     12752.0
# 9             4.0     12043.0
#
# [10 rows x 25 columns]

# %%
merged_df.duplicated(subset=['Product_ID', 'Customer_ID','Transaction_ID']).sum()
# Out:
# 0

# %%
duplicate_rows=merged_df[merged_df.duplicated(subset=['Product_ID','Transaction_ID'],keep=False)]
duplicate_rows
# Out:
#        Product_ID Product Name         Category       Price  Stock_Level  \
# 0             202         Book  Home Appliances  838.665080          290
# 1             202         Book  Home Appliances  838.665080          290
# 2             202         Book  Home Appliances  838.665080          290
# 3             202         Book  Home Appliances  838.665080          290
# 4             202         Book  Home Appliances  838.665080          290
# ...           ...          ...              ...         ...          ...
# 20622         667        Phone         Clothing  143.191788           57
# 20623         667        Phone         Clothing  143.191788           57
# 20624         667        Phone         Clothing  143.191788           57
# 20625         667        Phone         Clothing  143.191788           57
# 20626         667        Phone         Clothing  143.191788           57
#
#          Supplier  Discount  Rating_transaction  Transaction_ID  \
# 0      Supplier C         3                   3        170091.0
# 1      Supplier C         3                   3        170091.0
# 2      Supplier C         3                   3        170091.0
# 3      Supplier C         3                   3        170091.0
# 4      Supplier C         3                   3        135195.0
# ...           ...       ...                 ...             ...
# 20622  Supplier C        25                   3        131367.0
# 20623  Supplier C        25                   3        149437.0
# 20624  Supplier C        25                   3        149437.0
# 20625  Supplier C        25                   3        149437.0
# 20626  Supplier C        25                   3        149437.0
#
#                    Shipping_Date  ... Customer_Name   Age  Gender  \
# 0     1970-01-01 00:26:50.640000  ...           Bob  38.0    Male
# 1     1970-01-01 00:26:50.640000  ...           Bob  37.0    Male
# 2     1970-01-01 00:26:50.640000  ...           Bob  66.0  Female
# 3     1970-01-01 00:26:50.640000  ...       Unknown  45.0  Female
# 4     1970-01-01 00:26:51.410400  ...           Bob  38.0    Male
# ...                          ...  ...           ...   ...     ...
# 20622 1970-01-01 00:26:58.128000  ...           Eve  20.0   Other
# 20623 1970-01-01 00:27:01.630800  ...       Charlie  55.0    Male
# 20624 1970-01-01 00:27:01.630800  ...         Alice  56.0   Other
# 20625 1970-01-01 00:27:01.630800  ...           Bob  32.0    Male
# 20626 1970-01-01 00:27:01.630800  ...           Eve  20.0   Other
#
#             Location Product_Category       Purchase Date  Purchase Amount  \
# 0      San Francisco             Toys 2020-03-02 23:00:00       134.311447
# 1            Chicago            Books 2020-03-06 22:00:00       475.639185
# 2        Los Angeles  Home Appliances 2020-03-09 07:00:00       257.954370
# 3           New York         Clothing 2020-03-18 04:00:00        12.022306
# 4      San Francisco             Toys 2020-03-02 23:00:00       134.311447
# ...              ...              ...                 ...              ...
# 20622        Houston            Books 2020-03-20 02:00:00       199.706143
# 20623    Los Angeles  Home Appliances 2020-01-26 05:00:00       149.786219
# 20624        Houston      Electronics 2020-01-27 05:00:00       491.201865
# 20625        Houston  Home Appliances 2020-01-31 04:00:00       384.187046
# 20626        Houston            Books 2020-03-20 02:00:00       199.706143
#
#       Payment_Method Rating_customer Customer_ID
# 0      Bank Transfer             3.0     12752.0
# 1      Bank Transfer             4.0     12043.0
# 2      Bank Transfer             3.0     14904.0
# 3               Cash             4.0     12989.0
# 4      Bank Transfer             3.0     12752.0
# ...              ...             ...         ...
# 20622         PayPal             4.0     18105.0
# 20623  Bank Transfer             2.0     13627.0
# 20624  Bank Transfer             3.0     10667.0
# 20625           Cash             2.0     17002.0
# 20626         PayPal             4.0     18105.0
#
# [6996 rows x 25 columns]

# %%
aggregated_df = merged_df.groupby(['Product_ID', 'Transaction_ID']).agg({
    'Purchase Amount': 'sum',  # Summing up the purchase amount for the same Product_ID and Transaction_ID
    'Rating_customer': 'mean',          # Averaging ratings if applicable
    'Customer_ID': 'first',# Keeping the first customer ID or using another logic
    'Customer_Name': 'first'
}).reset_index()

aggregated_df
# Out:
#       Product_ID  Transaction_ID  Purchase Amount  Rating_customer  \
# 0            100        140600.0       661.482284              3.5
# 1            100        152893.0       661.482284              3.5
# 2            100        172805.0       661.482284              3.5
# 3            100        195998.0       661.482284              3.5
# 4            101        106406.0       191.821720              5.0
# ...          ...             ...              ...              ...
# 3501         998        135222.0      1232.592483              3.4
# 3502         998        149812.0      1232.592483              3.4
# 3503         998        164106.0      1232.592483              3.4
# 3504         998        165481.0      1232.592483              3.4
# 3505         998        171849.0      1232.592483              3.4
#
#       Customer_ID Customer_Name
# 0         13778.0           Bob
# 1         13778.0           Bob
# 2         13778.0           Bob
# 3         13778.0           Bob
# 4         16783.0       Charlie
# ...           ...           ...
# 3501      10004.0       Unknown
# 3502      10004.0       Unknown
# 3503      10004.0       Unknown
# 3504      10004.0       Unknown
# 3505      10004.0       Unknown
#
# [3506 rows x 6 columns]

# %% [markdown]
# # Feature Engineering
#   **total purchase amount for each customer**
#
#   **frequency of  product return**
#
#   **Average feedback rating**
#
#   **time difference between the last and the latest purchase**

# %%
merged_df.columns
# Out:
# Index(['Product_ID', 'Product Name', 'Category', 'Price', 'Stock_Level',
#        'Supplier', 'Discount', 'Rating_transaction', 'Transaction_ID',
#        'Shipping_Date', 'Delivery_Status', 'Return_Status', 'Feedback_Rating',
#        'Return_Reason', 'Shipping_Date_only', 'Customer_Name', 'Age', 'Gender',
#        'Location', 'Product_Category', 'Purchase Date', 'Purchase Amount',
#        'Payment_Method', 'Rating_customer', 'Customer_ID'],
#       dtype='object')

# %%
# total Purchase amount for each customer
merged_df['Total_purchase_amt']=merged_df.groupby('Customer_ID')['Purchase Amount'].transform('sum')
merged_df['Total_purchase_amt']
# Out:
# 0         671.557233
# 1        2378.195923
# 2        1289.771850
# 3          60.111529
# 4         671.557233
#             ...
# 20622    1198.236859
# 20623    1930.534791
# 20624    2947.211191
# 20625    2305.122276
# 20626    1198.236859
# Name: Total_purchase_amt, Length: 8161, dtype: float64

# %%
merged_df['Return_Status']
# Out:
# 0            Returned
# 1            Returned
# 2            Returned
# 3            Returned
# 4        Not Returned
#              ...
# 20622    Not Returned
# 20623    Not Returned
# 20624    Not Returned
# 20625    Not Returned
# 20626    Not Returned
# Name: Return_Status, Length: 8161, dtype: object

# %%
#frequency of return( we use sum instead of count because count only count not null values)
merged_df['Return_count']=merged_df.groupby('Customer_ID')['Return_Status'].transform(lambda i:(i=='Returned').sum())
merged_df.head(10)
# Out:
#    Product_ID Product Name         Category      Price  Stock_Level  \
# 0         202         Book  Home Appliances  838.66508          290
# 1         202         Book  Home Appliances  838.66508          290
# 2         202         Book  Home Appliances  838.66508          290
# 3         202         Book  Home Appliances  838.66508          290
# 4         202         Book  Home Appliances  838.66508          290
# 5         202         Book  Home Appliances  838.66508          290
# 6         202         Book  Home Appliances  838.66508          290
# 7         202         Book  Home Appliances  838.66508          290
# 8         202         Book  Home Appliances  838.66508          290
# 9         202         Book  Home Appliances  838.66508          290
#
#      Supplier  Discount  Rating_transaction  Transaction_ID  \
# 0  Supplier C         3                   3        170091.0
# 1  Supplier C         3                   3        170091.0
# 2  Supplier C         3                   3        170091.0
# 3  Supplier C         3                   3        170091.0
# 4  Supplier C         3                   3        135195.0
# 5  Supplier C         3                   3        135195.0
# 6  Supplier C         3                   3        135195.0
# 7  Supplier C         3                   3        135195.0
# 8  Supplier C         3                   3        195084.0
# 9  Supplier C         3                   3        195084.0
#
#                Shipping_Date  ...  Gender       Location  Product_Category  \
# 0 1970-01-01 00:26:50.640000  ...    Male  San Francisco              Toys
# 1 1970-01-01 00:26:50.640000  ...    Male        Chicago             Books
# 2 1970-01-01 00:26:50.640000  ...  Female    Los Angeles   Home Appliances
# 3 1970-01-01 00:26:50.640000  ...  Female       New York          Clothing
# 4 1970-01-01 00:26:51.410400  ...    Male  San Francisco              Toys
# 5 1970-01-01 00:26:51.410400  ...    Male        Chicago             Books
# 6 1970-01-01 00:26:51.410400  ...  Female    Los Angeles   Home Appliances
# 7 1970-01-01 00:26:51.410400  ...  Female       New York          Clothing
# 8 1970-01-01 00:26:52.278000  ...    Male  San Francisco              Toys
# 9 1970-01-01 00:26:52.278000  ...    Male        Chicago             Books
#
#         Purchase Date Purchase Amount Payment_Method  Rating_customer  \
# 0 2020-03-02 23:00:00      134.311447  Bank Transfer              3.0
# 1 2020-03-06 22:00:00      475.639185  Bank Transfer              4.0
# 2 2020-03-09 07:00:00      257.954370  Bank Transfer              3.0
# 3 2020-03-18 04:00:00       12.022306           Cash              4.0
# 4 2020-03-02 23:00:00      134.311447  Bank Transfer              3.0
# 5 2020-03-06 22:00:00      475.639185  Bank Transfer              4.0
# 6 2020-03-09 07:00:00      257.954370  Bank Transfer              3.0
# 7 2020-03-18 04:00:00       12.022306           Cash              4.0
# 8 2020-03-02 23:00:00      134.311447  Bank Transfer              3.0
# 9 2020-03-06 22:00:00      475.639185  Bank Transfer              4.0
#
#   Customer_ID Total_purchase_amt Return_count
# 0     12752.0         671.557233          3.0
# 1     12043.0        2378.195923          3.0
# 2     14904.0        1289.771850          3.0
# 3     12989.0          60.111529          3.0
# 4     12752.0         671.557233          3.0
# 5     12043.0        2378.195923          3.0
# 6     14904.0        1289.771850          3.0
# 7     12989.0          60.111529          3.0
# 8     12752.0         671.557233          3.0
# 9     12043.0        2378.195923          3.0
#
# [10 rows x 27 columns]

# %%
#Average feedback rating
merged_df['Avg_feedback_rating']=merged_df.groupby('Customer_ID')['Feedback_Rating'].transform('mean')
merged_df.head(20)
# Out:
#     Product_ID Product Name         Category      Price  Stock_Level  \
# 0          202         Book  Home Appliances  838.66508          290
# 1          202         Book  Home Appliances  838.66508          290
# 2          202         Book  Home Appliances  838.66508          290
# 3          202         Book  Home Appliances  838.66508          290
# 4          202         Book  Home Appliances  838.66508          290
# 5          202         Book  Home Appliances  838.66508          290
# 6          202         Book  Home Appliances  838.66508          290
# 7          202         Book  Home Appliances  838.66508          290
# 8          202         Book  Home Appliances  838.66508          290
# 9          202         Book  Home Appliances  838.66508          290
# 10         202         Book  Home Appliances  838.66508          290
# 11         202         Book  Home Appliances  838.66508          290
# 12         202         Book  Home Appliances  838.66508          290
# 13         202         Book  Home Appliances  838.66508          290
# 14         202         Book  Home Appliances  838.66508          290
# 15         202         Book  Home Appliances  838.66508          290
# 16         202         Book  Home Appliances  838.66508          290
# 17         202         Book  Home Appliances  838.66508          290
# 18         202         Book  Home Appliances  838.66508          290
# 19         202         Book  Home Appliances  838.66508          290
#
#       Supplier  Discount  Rating_transaction  Transaction_ID  \
# 0   Supplier C         3                   3        170091.0
# 1   Supplier C         3                   3        170091.0
# 2   Supplier C         3                   3        170091.0
# 3   Supplier C         3                   3        170091.0
# 4   Supplier C         3                   3        135195.0
# 5   Supplier C         3                   3        135195.0
# 6   Supplier C         3                   3        135195.0
# 7   Supplier C         3                   3        135195.0
# 8   Supplier C         3                   3        195084.0
# 9   Supplier C         3                   3        195084.0
# 10  Supplier C         3                   3        195084.0
# 11  Supplier C         3                   3        195084.0
# 12  Supplier C         3                   3        106090.0
# 13  Supplier C         3                   3        106090.0
# 14  Supplier C         3                   3        106090.0
# 15  Supplier C         3                   3        106090.0
# 16  Supplier C         3                   3        111561.0
# 17  Supplier C         3                   3        111561.0
# 18  Supplier C         3                   3        111561.0
# 19  Supplier C         3                   3        111561.0
#
#                 Shipping_Date  ...       Location Product_Category  \
# 0  1970-01-01 00:26:50.640000  ...  San Francisco             Toys
# 1  1970-01-01 00:26:50.640000  ...        Chicago            Books
# 2  1970-01-01 00:26:50.640000  ...    Los Angeles  Home Appliances
# 3  1970-01-01 00:26:50.640000  ...       New York         Clothing
# 4  1970-01-01 00:26:51.410400  ...  San Francisco             Toys
# 5  1970-01-01 00:26:51.410400  ...        Chicago            Books
# 6  1970-01-01 00:26:51.410400  ...    Los Angeles  Home Appliances
# 7  1970-01-01 00:26:51.410400  ...       New York         Clothing
# 17      12043.0        2378.195923          3.0                 3.0
# 18      14904.0        1289.771850          3.0                 3.0
# 19      12989.0          60.111529          3.0                 3.0
#
# [20 rows x 28 columns]

# %%
#time difference between the last purchase and the current date
merged_df['Days_since_last_purchase']=(pd.Timestamp.now()-merged_df.groupby('Customer_ID')['Purchase Date'].transform('max')).dt.days
merged_df.head(10)
# Out:
#    Product_ID Product Name         Category      Price  Stock_Level  \
# 0         202         Book  Home Appliances  838.66508          290
# 1         202         Book  Home Appliances  838.66508          290
# 2         202         Book  Home Appliances  838.66508          290
# 3         202         Book  Home Appliances  838.66508          290
# 4         202         Book  Home Appliances  838.66508          290
# 5         202         Book  Home Appliances  838.66508          290
# 6         202         Book  Home Appliances  838.66508          290
# 7         202         Book  Home Appliances  838.66508          290
# 8         202         Book  Home Appliances  838.66508          290
# 9         202         Book  Home Appliances  838.66508          290
#
#      Supplier  Discount  Rating_transaction  Transaction_ID  \
# 0  Supplier C         3                   3        170091.0
# 1  Supplier C         3                   3        170091.0
# 2  Supplier C         3                   3        170091.0
# 3  Supplier C         3                   3        170091.0
# 4  Supplier C         3                   3        135195.0
# 5  Supplier C         3                   3        135195.0
# 6  Supplier C         3                   3        135195.0
# 7  Supplier C         3                   3        135195.0
# 8  Supplier C         3                   3        195084.0
# 9  Supplier C         3                   3        195084.0
#
#                Shipping_Date  ... Product_Category       Purchase Date  \
# 0 1970-01-01 00:26:50.640000  ...             Toys 2020-03-02 23:00:00
# 1 1970-01-01 00:26:50.640000  ...            Books 2020-03-06 22:00:00
# 2 1970-01-01 00:26:50.640000  ...  Home Appliances 2020-03-09 07:00:00
# 3 1970-01-01 00:26:50.640000  ...         Clothing 2020-03-18 04:00:00
# 4 1970-01-01 00:26:51.410400  ...             Toys 2020-03-02 23:00:00
# 5 1970-01-01 00:26:51.410400  ...            Books 2020-03-06 22:00:00
# 6 1970-01-01 00:26:51.410400  ...  Home Appliances 2020-03-09 07:00:00
# 7 1970-01-01 00:26:51.410400  ...         Clothing 2020-03-18 04:00:00
# 8 1970-01-01 00:26:52.278000  ...             Toys 2020-03-02 23:00:00
# 9 1970-01-01 00:26:52.278000  ...            Books 2020-03-06 22:00:00
#
#    Purchase Amount Payment_Method Rating_customer Customer_ID  \
# 0       134.311447  Bank Transfer             3.0     12752.0
# 1       475.639185  Bank Transfer             4.0     12043.0
# 2       257.954370  Bank Transfer             3.0     14904.0
# 3        12.022306           Cash             4.0     12989.0
# 4       134.311447  Bank Transfer             3.0     12752.0
# 5       475.639185  Bank Transfer             4.0     12043.0
# 6       257.954370  Bank Transfer             3.0     14904.0
# 7        12.022306           Cash             4.0     12989.0
# 8       134.311447  Bank Transfer             3.0     12752.0
# 9       475.639185  Bank Transfer             4.0     12043.0
#
#    Total_purchase_amt Return_count Avg_feedback_rating  \
# 0          671.557233          3.0                 3.0
# 1         2378.195923          3.0                 3.0
# 2         1289.771850          3.0                 3.0
# 3           60.111529          3.0                 3.0
# 4          671.557233          3.0                 3.0
# 5         2378.195923          3.0                 3.0
# 6         1289.771850          3.0                 3.0
# 7           60.111529          3.0                 3.0
# 8          671.557233          3.0                 3.0
# 9         2378.195923          3.0                 3.0
#
#   Days_since_last_purchase
# 0                   1695.0
# 1                   1691.0
# 2                   1689.0
# 3                   1680.0
# 4                   1695.0
# 5                   1691.0
# 6                   1689.0
# 7                   1680.0
# 8                   1695.0
# 9                   1691.0
#
# [10 rows x 29 columns]

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2024-10-23 20:35:10.633149')

# %%
merged_df.head(20)
# Out:
#     Product_ID Product Name         Category      Price  Stock_Level  \
# 0          202         Book  Home Appliances  838.66508          290
# 1          202         Book  Home Appliances  838.66508          290
# 2          202         Book  Home Appliances  838.66508          290
# 3          202         Book  Home Appliances  838.66508          290
# 4          202         Book  Home Appliances  838.66508          290
# 5          202         Book  Home Appliances  838.66508          290
# 6          202         Book  Home Appliances  838.66508          290
# 7          202         Book  Home Appliances  838.66508          290
# 8          202         Book  Home Appliances  838.66508          290
# 9          202         Book  Home Appliances  838.66508          290
# 10         202         Book  Home Appliances  838.66508          290
# 11         202         Book  Home Appliances  838.66508          290
# 12         202         Book  Home Appliances  838.66508          290
# 13         202         Book  Home Appliances  838.66508          290
# 14         202         Book  Home Appliances  838.66508          290
# 15         202         Book  Home Appliances  838.66508          290
# 16         202         Book  Home Appliances  838.66508          290
# 17         202         Book  Home Appliances  838.66508          290
# 18         202         Book  Home Appliances  838.66508          290
# 19         202         Book  Home Appliances  838.66508          290
#
#       Supplier  Discount  Rating_transaction  Transaction_ID  \
# 0   Supplier C         3                   3        170091.0
# 1   Supplier C         3                   3        170091.0
# 2   Supplier C         3                   3        170091.0
# 3   Supplier C         3                   3        170091.0
# 4   Supplier C         3                   3        135195.0
# 5   Supplier C         3                   3        135195.0
# 6   Supplier C         3                   3        135195.0
# 7   Supplier C         3                   3        135195.0
# 8   Supplier C         3                   3        195084.0
# 9   Supplier C         3                   3        195084.0
# 10  Supplier C         3                   3        195084.0
# 11  Supplier C         3                   3        195084.0
# 12  Supplier C         3                   3        106090.0
# 13  Supplier C         3                   3        106090.0
# 14  Supplier C         3                   3        106090.0
# 15  Supplier C         3                   3        106090.0
# 16  Supplier C         3                   3        111561.0
# 17  Supplier C         3                   3        111561.0
# 18  Supplier C         3                   3        111561.0
# 19  Supplier C         3                   3        111561.0
#
#                 Shipping_Date  ... Product_Category       Purchase Date  \
# 0  1970-01-01 00:26:50.640000  ...             Toys 2020-03-02 23:00:00
# 1  1970-01-01 00:26:50.640000  ...            Books 2020-03-06 22:00:00
# 2  1970-01-01 00:26:50.640000  ...  Home Appliances 2020-03-09 07:00:00
# 3  1970-01-01 00:26:50.640000  ...         Clothing 2020-03-18 04:00:00
# 4  1970-01-01 00:26:51.410400  ...             Toys 2020-03-02 23:00:00
# 5  1970-01-01 00:26:51.410400  ...            Books 2020-03-06 22:00:00
# 6  1970-01-01 00:26:51.410400  ...  Home Appliances 2020-03-09 07:00:00
# 7  1970-01-01 00:26:51.410400  ...         Clothing 2020-03-18 04:00:00
#        Rating_customer   Customer_ID  Total_purchase_amt  Return_count  \
# count      7749.000000   8160.000000         8160.000000   8160.000000
# mean          2.900761  15035.360662         1548.454047      3.159804
# min           1.000000  10001.000000            0.000000      0.000000
# 25%           2.000000  12590.000000          652.296798      2.000000
# 50%           3.000000  15109.000000         1351.551621      3.000000
# 75%           4.000000  17404.000000         2177.775999      4.000000
# max           5.000000  19996.000000         6374.397713     12.000000
# std           1.382028   2863.546766         1170.624544      2.027861
#
#        Avg_feedback_rating  Days_since_last_purchase
# count          8143.000000               7802.000000
# mean              2.844058               1713.226224
# min              -1.000000               1674.000000
# 25%               2.400000               1692.000000
# 50%               2.857143               1712.000000
# 75%               3.333333               1734.000000
# max               5.000000               1757.000000
# std               0.765721                 24.111824

# %%
merged_df['Product_Category'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category'>

# %%
df_num=merged_df.select_dtypes(include="number")
df_num.columns
# Out:
# Index(['Product_ID', 'Price', 'Stock_Level', 'Discount', 'Rating_transaction',
#        'Transaction_ID', 'Feedback_Rating', 'Age', 'Purchase Amount',
#        'Rating_customer', 'Customer_ID', 'Total_purchase_amt', 'Return_count',
#        'Avg_feedback_rating', 'Days_since_last_purchase'],
#       dtype='object')

# %%
numeric_cols=df_num.columns
plt.figure(figsize=(15, 10))
n_cols = 4  
n_rows = (len(numeric_cols) + n_cols - 1) // n_cols  
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(n_rows, n_cols, i)  
    sns.boxplot(y=df_num[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
numeric_cols=df_num.columns
plt.figure(figsize=(15, 10))
n_cols = 4  
n_rows = (len(numeric_cols) + n_cols - 1) // n_cols  
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(n_rows, n_cols, i)  
    sns.histplot(x=df_num[col])
    plt.title(col)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Mir Abdul Malique\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# To compare each value, since there is a huge scale to convert into a similar scale we use min-max scale normalization
from sklearn.preprocessing import MinMaxScaler
le=MinMaxScaler()
df_norm=le.fit_transform(df_num)

# %%
pd.DataFrame(df_norm).describe().T
# Out:
#      count      mean       std  min       25%       50%       75%  max
# 0   8161.0  0.511441  0.294501  0.0  0.252784  0.515590  0.770601  1.0
# 1   8161.0  0.484675  0.272440  0.0  0.264978  0.490359  0.697770  1.0
# 2   8161.0  0.469129  0.284173  0.0  0.226000  0.460000  0.710000  1.0
# 3   8161.0  0.513658  0.295943  0.0  0.265306  0.530612  0.775510  1.0
# 4   8161.0  0.500796  0.347610  0.0  0.250000  0.500000  0.750000  1.0
# 5   8138.0  0.491717  0.286512  0.0  0.239893  0.493711  0.737899  1.0
# 6   8138.0  0.640637  0.262485  0.0  0.500000  0.666667  0.833333  1.0
# 7   7749.0  0.501045  0.286155  0.0  0.254902  0.503849  0.745098  1.0
# 8   7749.0  0.501582  0.275892  0.0  0.280568  0.506117  0.727592  1.0
# 9   7749.0  0.475190  0.345507  0.0  0.250000  0.500000  0.750000  1.0
# 10  8160.0  0.503688  0.286498  0.0  0.259030  0.511056  0.740670  1.0
# 11  8160.0  0.242918  0.183645  0.0  0.102331  0.212028  0.341644  1.0
# 12  8160.0  0.263317  0.168988  0.0  0.166667  0.250000  0.333333  1.0
# 13  8143.0  0.640676  0.127620  0.0  0.566667  0.642857  0.722222  1.0
# 14  7802.0  0.472605  0.290504  0.0  0.216867  0.457831  0.722892  1.0
